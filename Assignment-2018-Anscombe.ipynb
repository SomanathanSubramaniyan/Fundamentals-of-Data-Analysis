# %% [markdown]
# # Fundamentals of Data Analysis - Assignment 2018

# %% [markdown]
# ### Problem Statement
#
# Anscombe’s quartet dataset :
#
# 1. Explain the background to the dataset – who created it, when it was created, and any speculation you can ﬁnd regarding how it might have been created.
# 2. Plot the interesting aspects of the dataset.
# 3. Calculate the descriptive statistics of the variables in the dataset.
# 4. Explain why the dataset is interesting, referring to the plots and statistics above

# %% [markdown]
# ## 1. Anscombe's Quartet: Who Created,  when it was created  and how it might have been created

# %% [markdown]
# ***
# Anscombe's quartet comprises four datasets that have nearly identical simple descriptive statistics, yet appear very different when graphed. Each dataset consists of eleven (x,y) points. <br> <br>
# <font color=blue> Who Created the dataset </font>  ::  Frank Anscombe <br>
# <font color=blue> When it was constructed</font>   :: 1973 <br>
# ***

# %% [markdown]
# ## 2. Plot interesting aspect of the dataset

# %% [markdown]
# ***
# - Plot scatter and bar charts using Anscombe dataset
# - Matplotlib and Panda's python libraries are used for the plots
# ***

# %%
# import the Pandas
# Load the Anscombe data into Pandas dataset
import pandas as pd
# import matplot library to show the graph
from __future__ import division, print_function
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Set some parameters to apply to all plots. These can be overridden
# in each plot if desired
# Do not display top and right frame lines
# Remove grid lines, # Set backgound color to white
import matplotlib
matplotlib.rc('font', size = 15)
matplotlib.rc('axes.spines', top = True, right = True)
matplotlib.rc('axes', grid = True)
matplotlib.rc('axes', facecolor = 'white')

# Read the data from the anscombe CSV file and create a data frame
df = pd.read_csv(r"C:\Users\soman\Documents\Fundamentals-of-data-analysis\anscombe.csv")

df['y1-avg'] = 7.500909

# Plot the graph in the same row and size the each graph
#plot the 3 graphs x1 Vs y1 , x2 Vs y2 and x3 Vs y3 by accessing the dataframe
# SCATTER PLOT
fig, axes = plt.subplots(ncols=4, figsize=(25,3))
df.plot.scatter(x='x1', y='y1', color='Blue',ax=axes[0])
df.plot.scatter(x='x2', y='y2', color='Red',ax=axes[1])
df.plot.scatter(x='x3', y='y3', color='Green',ax=axes[2])
df.plot.scatter(x='x4', y='y4', color='violet',ax=axes[3])

#plot the graph
plt.show()

# BAR PLOT
fig, axes = plt.subplots(ncols=4, figsize=(30,3))
#plot the 3 graphs x1 Vs y1 , x2 Vs y2 and x3 Vs y3 by accessing the dataframe
df.plot.bar(x='x1', y='y1', color='Blue',ax=axes[0])
df.plot.bar(x='x2', y='y2', color='Red',ax=axes[1])
df.plot.bar(x='x3', y='y3', color='Green',ax=axes[2])
df.plot.bar(x='x4', y='y4', color='violet',ax=axes[3])


# Show the plot
plt.show()

# BOX PLOT
fig, axes = plt.subplots(ncols=4, figsize=(30,3))
#plot the 3 graphs x1 Vs y1 , x2 Vs y2 and x3 Vs y3 by accessing the dataframe
df.plot.box(x='x1', y='y1', color='Blue',ax=axes[0])
df.plot.box(x='x2', y='y2', color='Red',ax=axes[1])
df.plot.box(x='x3', y='y3', color='Green',ax=axes[2])
df.plot.box(x='x4', y='y4', color='violet',ax=axes[3])


# Show the plot
plt.show()

# %% [markdown]
# ***
# ## 3. Descriptive statistics of the variables in the dataset.
# ***

# %%
# import the Pandas
import pandas as pd
import numpy as np

# Read the data from the anscombe CSV file and create a data frame
df = pd.read_csv(r"C:\Users\soman\Documents\Fundamentals-of-data-analysis\anscombe.csv")  
df.loc[:,['x1','y1','x2','y2','x3','y3','x4','y4']].describe()
# Out:
#               x1         y1         x2         y2         x3         y3  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               x4         y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
df.loc[:,['x1','y1','x2','y2','x3','y3','x4','y4']]
# Out:
#     x1     y1  x2    y2  x3     y3  x4     y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %% [markdown]
# ***
# ## 4. Interesting aspects based on the graphs and Summary Stats
# ***

# %% [markdown]
# #### Data Set
# - Four sets of x and y data with 11 values in each set.
#
# #### Observations from summary statistics
# - x1 to x4 :: The mean/Average value of all the 4 data sets are same (9)
# - x1 to x4 :: The standard diviation is 3.3 from the mean
# - y1 to y4 :: The mean/Average value of all the 4 data sets are same (7.5)
# - y1 to y4 :: The standard diviation is 2.03 from the mean
#
# #### Observations from graphs
# - Dataset 1: Appear to follow a linear relationship with some variance.
# - Dataset 2: Fits a curve
# - Dataset 3: Linear relationship between x and y, except for one large outlier.
# - Dataset 4: Looks like x remains constant, except one outlier.
#
# **Conclusion** It is important to visualise the data as the differences are not too obvious/revealing in the summary statistics

# %% [markdown]
# ***
# ## End
# ***
